# %%
import torch
from d2l import torch as d2l
from torch.nn import functional as F

# %%
x=torch.arange(-5,5,0.1)
y=F.softmax(x,dim=0)
d2l.plt.plot(x,y)

# %%
x=torch.tensor([[2,4,2],[3,4,5]], dtype=torch.float32)


"""
softmax([2 ,[4 ,[2 )
         3]  4]  5]
"""


x,F.softmax(x,dim=1)
# Out:
# (tensor([[2., 4., 2.],
#          [3., 4., 5.]]),
#  tensor([[0.1065, 0.7870, 0.1065],
#          [0.0900, 0.2447, 0.6652]]))

# %%
p=torch.tensor([[2,4,2],[3,4,5]], dtype=torch.float32)
p,p.sum(),p.sum(dim=0),p.sum(dim=1)
#dim=0:[2,4,2]+[3,4,5]以对整行
#dim=1:[2  +[4  +[2   对整列
#       3]   4]   5]
# Out:
# (tensor([[2., 4., 2.],
#          [3., 4., 5.]]),
#  tensor(20.),
#  tensor([5., 8., 7.]),
#  tensor([ 8., 12.]))
